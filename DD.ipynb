# %% [markdown]
# <a href="https://colab.research.google.com/github/PaurasR/Durg_Detection-/blob/main/DD.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
DD = pd.read_csv('/content/Maragakis et al test SMILES with matched fingerprints without matched graph.csv')

# %%
DD
# Out:
#                                            SMILES_test  \
# 0    CCS(=O)(=O)c1ccc(CC(=O)Nc2nc3c(s2)CN(C[C@H]2CC...
# 1    COC(=O)N(C)[C@H]1CC[C@H](CC(=O)Nc2cc(-c3ccccc3...
# 2    CCNC(=O)CC(C)c1cccc(CC(=O)Nc2ccc(CCCCc3nnc(NC(...
# 3           N[C@@H](C(=O)O)[C@H]1C[C@@H](OCc2ccccc2)C1
# 4    CCCCC(=O)c1c(O)c(=O)c(C(=O)NCc2cccc(Cl)c2F)cn1...
# ..                                                 ...
# 99   Cc1ncoc1-c1ccc(C(C)NC(=O)[C@@H]2C[C@@H](O)CN2C...
# 100  Cc1ccc(-c2noc(C)c2COc2cnc(C(=O)N[C@H]3CC[C@@H]...
# 101  C[C@@H](C(=O)NC(C(=O)N1C[C@@H](OCCOCCOCCOCCO)C...
# 102  CC(C)(C)[C@H]1CC[C@@H](N2CCC(n3cc(C=NO)c4cccnc...
# 103            CC(C)(C)CCc1cccc(O[C@H]2C[C@@H](N)C2)c1
#
#                                               SMILES_1  Recovers_Exact_Graph
# 0    CCS(=O)(=O)c1ccc(CC(=O)Nc2nc3c(s2)CN(C[C@H]2CC...                  True
# 1    COC(=O)N(C)[C@H]1CC[C@H](CC(=O)Nc2cc(-c3ccccc3...                  True
# ...

# %%
DD.shape
# Out:
# (104, 3)

# %%
DD = pd.read_csv('/content/Maragakis et al DUDE docking scores and vortex properties.csv')

# %%
DD
# Out:
#                                                        ID      score  \
# 0                                      (DESMILES:6968009)  -182.9720
# 1                                      (DESMILES:1090761)  -172.2308
# 2       (DESMILES:11628423,DESMILES:152270,DESMILES:79...  -166.7088
# 3                                      (DESMILES:1708673)  -164.8812
# 4                     (DESMILES:2774222,DESMILES:6558061)  -164.5410
# ...                                                   ...        ...
# 637287                                 (DESMILES:9169907)  1332.9660
# 637288                                 (DESMILES:4328101)  1369.0930
# 637289                (DESMILES:1740614,DESMILES:8238485)  1526.5030
# 637290              (DESMILES:10964426,DESMILES:11659229)  1944.4700
# 637291  (DESMILES:3388456,DESMILES:4452166,DESMILES:48...  3104.4550
#
#                                                    SMILES target      MW  \
# ...

# %%
DD.shape
# Out:
# (637292, 25)

# %%
null = DD.isnull()

# %%
null.sum()
# Out:
# ID                   0
# score                0
# SMILES               0
# target               0
# MW                   0
# MW_EXACT             0
# XLogP                0
# HBA                  0
# HBD                  0
# LIPINSKI_COUNT       0
# RO3_COUNT            0
# TPSA_NO              0
# TPSA_NOPS            0
# HAC                  0
# AtomCount            0
# BondCount            0
# FSP3                 0
# RotBondCount         0
# HalogenCount         0
# SpiroCount           0
# PosCount             0
# NegCount             0
# ComponentCount       0
# SimpleRingCount      0
# AromaticRingCount    0
# dtype: int64

# %%
DD.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 637292 entries, 0 to 637291
# Data columns (total 25 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   ID                 637292 non-null  object
#  1   score              637292 non-null  float64
#  2   SMILES             637292 non-null  object
#  3   target             637292 non-null  object
#  4   MW                 637292 non-null  float64
#  5   MW_EXACT           637292 non-null  float64
#  6   XLogP              637292 non-null  float64
#  7   HBA                637292 non-null  int64
#  8   HBD                637292 non-null  int64
#  9   LIPINSKI_COUNT     637292 non-null  int64
#  10  RO3_COUNT          637292 non-null  int64
#  11  TPSA_NO            637292 non-null  float64
#  12  TPSA_NOPS          637292 non-null  float64
#  13  HAC                637292 non-null  int64
#  14  AtomCount          637292 non-null  int64
# ...

# %%
DD.describe()
# Out:
#               score             MW       MW_EXACT          XLogP  \
# count  6.372920e+05  637292.000000  637292.000000  637292.000000
# mean   2.338004e+02     349.160322     348.805554       2.948071
# std    2.091391e+05      83.310572      83.211183       1.916836
# min   -2.966729e+02     100.120000     100.052429      -9.560000
# 25%   -5.739972e+01     291.390000     291.158295       1.780000
# 50%   -4.649365e+01     350.350000     350.033936       2.920000
# 75%   -3.792394e+01     414.350000     413.918884       4.130000
# max    1.668775e+08     499.990000     499.331116      12.640000
#
#                  HBA            HBD  LIPINSKI_COUNT      RO3_COUNT  \
# count  637292.000000  637292.000000   637292.000000  637292.000000
# mean        5.368205       1.443718        0.136319       2.059532
# std         1.962204       0.985895        0.345152       0.926610
# min         1.000000       0.000000        0.000000       0.000000
# ...

# %%
# !pip install -q condacolab
import condacolab
condacolab.install()
# Out:
# ✨🍰✨ Everything looks OK!

# %%
# Install RDKit using Conda
# !conda install -c conda-forge rdkit -y
# Out:
# Channels:
#  - conda-forge
# Platform: linux-64
# done
# done
#
#
# ==> WARNING: A newer version of conda exists. <==
#     current version: 23.11.0
#     latest version: 24.9.2
#
# Please update conda by running
#
#     $ conda update -n base -c conda-forge conda
#
#
#
# ## Package Plan ##
#
#   environment location: /usr/local
#
#   added / updated specs:
#     - rdkit
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     brotli-1.1.0               |       hd590300_1          19 KB  conda-forge
#     brotli-bin-1.1.0           |       hd590300_1          19 KB  conda-forge
#     ca-certificates-2024.8.30  |       hbcca054_0         155 KB  conda-forge
#     cairo-1.18.0               |       h3faef2a_0         959 KB  conda-forge
#     certifi-2024.8.30          |     pyhd8ed1ab_0         160 KB  conda-forge
# ...

# %%
import rdkit
print(rdkit.__version__)
# Out:
# 2024.03.6

# %%
# !pip install deepchem
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.8/60.8 kB 2.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 17.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.2/41.2 MB 13.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 301.8/301.8 kB 18.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.3/13.3 MB 78.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.2/6.2 MB 72.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 536.2/536.2 kB 31.9 MB/s eta 0:00:00
# ...

# %%
import deepchem as dc
print(dc.__version__)
# Out:
# No normalization for SPS. Feature removed!
# No normalization for AvgIpc. Feature removed!
# wandb: WARNING W&B installed but not logged in.  Run `wandb login` or set the WANDB_API_KEY env variable.
# WARNING:tensorflow:From /usr/local/lib/python3.10/dist-packages/tensorflow/python/util/deprecation.py:588: calling function (from tensorflow.python.eager.polymorphic_function.polymorphic_function) with experimental_relax_shapes is deprecated and will be removed in a future version.
# Instructions for updating:
# experimental_relax_shapes is deprecated, use reduce_retracing instead
# wandb: WARNING W&B installed but not logged in.  Run `wandb login` or set the WANDB_API_KEY env variable.
# Skipped loading modules with pytorch-geometric dependency, missing a dependency. No module named 'torch_geometric'
# ...

# %%
from rdkit import Chem
from rdkit.Chem import AllChem

# Convert SMILES string to a molecule object
smiles = "CCO"
molecule = Chem.MolFromSmiles(smiles)

# Generate Morgan Fingerprint (radius 2, 2048 bits)
fingerprint = AllChem.GetMorganFingerprintAsBitVect(molecule, 2, nBits=2048)
# Out:
# [22:34:02] DEPRECATION WARNING: please use MorganGenerator

# %%
DD['SMILES']
# Out:
# 0         C#Cc1ccccc1-c1c(/C(N)=N/O)cc(C(F)(F)F)cc1-c1cc...
# 1                  CCOC(=O)c1cn[nH]c1S(=O)(=O)NC(CN)C1CCCC1
# 2         Cn1cnc(Nc2nc(N[C@H](CNC(=O)O)c3ccc(F)cc3)nc(N3...
# 3         Cc1ccc(Oc2ccc(Nc3ncnc4cc(CNC(=O)O)[nH]c34)cc2C...
# 4                CC(NC(=O)O)[C@H](CC1CCCCC1)NC(=O)OC(C)(C)C
#                                 ...
# 637287                 CC1(C)CNCCC1NC(=O)C1CCCC(C(F)(F)F)C1
# 637288                             CCNC1CC=CC2=C1C(NC)=CCC2
# 637289       C[C@H](NCCNC[C@@H]1CCC2C[C@@H]1C2(C)C)C1CCCCC1
# 637290                           CC=C(CN1CCCC1)C(C)N1CCCCC1
# 637291    C[C@@H]1[C@@H](NCCNC[C@@H]2CC[C@H]3CC2C3(C)C)C...
# Name: SMILES, Length: 637292, dtype: object

# %%
DD.head()
# Out:
#                                                   ID     score  \
# 0                                 (DESMILES:6968009) -182.9720
# 1                                 (DESMILES:1090761) -172.2308
# 2  (DESMILES:11628423,DESMILES:152270,DESMILES:79... -166.7088
# 3                                 (DESMILES:1708673) -164.8812
# 4                (DESMILES:2774222,DESMILES:6558061) -164.5410
#
#                                               SMILES target      MW  \
# 0  C#Cc1ccccc1-c1c(/C(N)=N/O)cc(C(F)(F)F)cc1-c1cc...    ada  396.36
# 1           CCOC(=O)c1cn[nH]c1S(=O)(=O)NC(CN)C1CCCC1    ada  330.40
# 2  Cn1cnc(Nc2nc(N[C@H](CNC(=O)O)c3ccc(F)cc3)nc(N3...    ada  457.46
# 3  Cc1ccc(Oc2ccc(Nc3ncnc4cc(CNC(=O)O)[nH]c34)cc2C...    ada  404.42
# 4         CC(NC(=O)O)[C@H](CC1CCCCC1)NC(=O)OC(C)(C)C    ada  314.42
#
#      MW_EXACT  XLogP  HBA  HBD  LIPINSKI_COUNT  ...  BondCount   FSP3  \
# 0  396.108551   5.95    4    3               1  ...         31  0.045
# ...

# %%
X = DD.iloc[:, :-1].values
y = DD.iloc[:, -1].values

# %%
print(X)
# Out:
# [['(DESMILES:6968009)' -182.972
#   'C#Cc1ccccc1-c1c(/C(N)=N/O)cc(C(F)(F)F)cc1-c1ccc(O)cc1' ... 0 1 3]
#  ['(DESMILES:1090761)' -172.2308
#   'CCOC(=O)c1cn[nH]c1S(=O)(=O)NC(CN)C1CCCC1' ... 0 1 2]
#  ['(DESMILES:11628423,DESMILES:152270,DESMILES:7998103)' -166.7088
#   'Cn1cnc(Nc2nc(N[C@H](CNC(=O)O)c3ccc(F)cc3)nc(N3CCOCC3)n2)c1' ... 0 1 4]
#  ...
#  ['(DESMILES:1740614,DESMILES:8238485)' 1526.503
#   'C[C@H](NCCNC[C@@H]1CCC2C[C@@H]1C2(C)C)C1CCCCC1' ... 0 1 3]
#  ['(DESMILES:10964426,DESMILES:11659229)' 1944.47
#   'CC=C(CN1CCCC1)C(C)N1CCCCC1' ... 0 1 2]
#  ['(DESMILES:3388456,DESMILES:4452166,DESMILES:4800681,DESMILES:7190955)'
#   3104.455
#   'C[C@@H]1[C@@H](NCCNC[C@@H]2CC[C@H]3CC2C3(C)C)C[C@H]2C[C@@H]1C2(C)C'
#   ... 0 1 4]]

# %%
print(y)
# Out:
# [3 1 3 ... 0 0 0]

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X,y,random_state=0,test_size=0.2)

# %%
X_train
# Out:
# array([['(DESMILES:840417)', -44.36876,
#         'Cc1ccc(S(=O)(=O)N2CCCC(C(=O)O)C2)s1', ..., 0, 1, 2],
#        ['(DESMILES:3411525)', -110.225,
#         'COc1ccc2ncc(F)c(CCN3CCC(F)(CN(C(=O)O)C(C)(C)C)C3)c2n1', ..., 0,
#         1, 3],
#        ['(DESMILES:4856314,DESMILES:8834295)', -39.64779,
#         'O=C(N[C@@H]1CCC[C@@H](C(=O)N2CCCC2)C1)c1ccc(-c2cccc(F)c2)nc1',
#         ..., 0, 1, 4],
#        ...,
#        ['(DESMILES:4921370,DESMILES:6047690)', -49.87091,
#         'NC(=O)c1nnc(N[C@@H]2CCCC[C@@H]2N)nc1Nc1cccc2c1cnn2[C@H]1CCOC1',
#         ..., 0, 1, 5],
#        ['(DESMILES:10365732,DESMILES:11441269,DESMILES:5051393)',
#         -32.648740000000004, 'N[C@H](C(=O)N1CCCC1)[C@@H](O)c1ccncc1',
#         ..., 0, 1, 2],
#        ['(DESMILES:10306506,DESMILES:9419039)', -51.18003,
#         'O=C(NCc1ccc(S(=O)(=O)c2cccc(C(F)(F)F)c2)cc1)[C@H]1CCCN1', ...,
#         0, 1, 3]], dtype=object)

# %%
Y_train
# Out:
# array([1, 2, 2, ..., 3, 1, 2])

# %%
Y_test
# Out:
# array([1, 1, 2, ..., 2, 1, 3])

# %%
X_test
# Out:
# array([['(DESMILES:5605618)', -17.977510000000002,
#         'CC1CN/C(=N/CCc2cc(Cl)ccc2Br)N1', ..., 0, 1, 2],
#        ['(DESMILES:10572459,DESMILES:9382603)', -66.28757,
#         'Nc1ccn([C@@H]2[C@@H](F)[C@H](CO)[C@H]2CO)c(=O)n1', ..., 0, 1, 2],
#        ['(DESMILES:10781637,DESMILES:5172335,DESMILES:9196741)',
#         -48.0079, 'COc1cccc([C@@H](C)NCC=Cc2c(C)cc(C)cc2C)c1', ..., 0, 1,
#         2],
#        ...,
#        ['(DESMILES:11448086,DESMILES:1980552)', -45.39008,
#         'COc1ccc([C@@H]2Cc3cc(C(F)(F)F)ccc3N(CCN3CCCC3)C(=O)[C@@H]2O)cc1',
#         ..., 0, 1, 4],
#        ['(DESMILES:1771747,DESMILES:6312869)', -32.59233,
#         'CC[C@@H](C(N)=O)N(C)Cc1ccccc1', ..., 0, 1, 1],
#        ['(DESMILES:9131199)', -76.12756,
#         'Cc1noc(COC(=O)c2cc(O)nc3ccccc23)n1', ..., 0, 1, 3]], dtype=object)

# %%
from sklearn.preprocessing import StandardScaler
